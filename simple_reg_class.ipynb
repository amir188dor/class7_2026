# %% [markdown]
# # 1- Simple Linear Regression
# - Relationship between two variables: Years of Experience (X) and Salary (y).
# - Predict new values depending upon this linear relationship.
# - Equation: Y = aX + b
#     - a = slope / function of X (how much salary increases per year)
#     - b = constant / intercept (base salary for 0 years of experience)
# - Algorithm: Works on minimizing the mean residual error.
# - Evaluation: R2 (R-Squared) method tells us the accuracy score.
# ```

# %% [markdown]
# ## Stage 1: Importing Libraries and Dataset

# %%
# Import fundamental libraries for data manipulation and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Fetching the Salary dataset directly from Github
url = 'https://raw.githubusercontent.com/amir188dor/class04_06_2024/main/Salary_Data.csv'
df = pd.read_csv(url)

# Display the first 5 rows to inspect the data structure
print("Dataset loaded successfully! Preview:")
print(df.head())

# %% [markdown]
# ## Stage 2: Splitting Dataset into X (Features) and y (Target)

# %%
# Task: Separate the dataset into Input Feature (X) and Output Target (y)
# Hint: X must be a 2D array/DataFrame, y must be a 1D vector

X = # WRITE YOUR CODE HERE (Select 'YearsExperience' as a list)
y = # WRITE YOUR CODE HERE (Select 'Salary' column)

# Print shapes to verify correctness
print("X shape (Matrix):", X.shape)
print("y shape (Vector):", y.shape)

# %% [markdown]
# ## Stage 3: Plotting Data (Exploratory Data Analysis)

# %%
# Visualizing the raw data points to check for a linear trend
plt.figure(figsize=(7, 4))

# Task: Plot a scatter plot of X vs y using blue dots
# WRITE YOUR CODE HERE

plt.title('Let\'s look at our data: Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary ($)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Stage 4: Train-Test Split (80% Train, 20% Test)

# %%
# Import the split tool from sklearn
from sklearn.model_selection import train_test_split

# Task: Split X and y into training and testing sets.
# Use test_size=0.2 (or test_size=1/3 as in the original notebook) and random_state=0
X_train, X_test, y_train, y_test = # WRITE YOUR CODE HERE

print(f"Data split complete!")
print(f"Training samples: {len(X_train)} | Testing samples: {len(X_test)}")

# %% [markdown]
# ## Stage 5: Fit Linear Regression Model (Training Phase)

# %%
# Import the Linear Regression model
from sklearn.linear_model import LinearRegression

# Task 1: Create the model instance
model = # WRITE YOUR CODE HERE

# Task 2: Train/Fit the model using ONLY the training datasets
# WRITE YOUR CODE HERE

print("Model training complete!")
# Print the extracted optimal parameters
print(f"Discovered Slope (a): {model.coef_[0]:.2f}")
print(f"Discovered Intercept (b): {model.intercept_:.2f}")

# %% [markdown]
# ## Stage 6: Plotting Model Line and Data (Visualizing Results)

# %%
# Visualizing the Regression Line against the Training data
plt.figure(figsize=(7, 4))
plt.scatter(X_train, y_train, color='orange', label='Actual Train Data')

# Task: Draw the red regression line using model predictions on X_train
# WRITE YOUR CODE HERE (Hint: use plt.plot)

plt.title('Linear Regression Model (Training Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary ($)')
plt.legend()
plt.show()

# %% [markdown]
# ## Stage 7: Testing / Evaluating Your Model (Model Fitness)

# %%
# Task: Calculate the accuracy (R2 Score) for both train and test data to check for Overfitting
train_accuracy = # WRITE YOUR CODE HERE (Hint: use model.score on training sets)
test_accuracy = # WRITE YOUR CODE HERE (Hint: use model.score on testing sets)

print(f"Score for training data (R2): {train_accuracy * 100:.2f}%")
print(f"Score for test data (R2): {test_accuracy * 100:.2f}%")

# %% [markdown]
# ## Stage 8: Prediction on Unknown / New Values

# %%
# Task: Predict the salary for new applicants with 2 years and 10 years of experience
# Hint: Pass values as a 2D array [[2], [10]]

new_data = np.array([[2], [10]])
predictions = # WRITE YOUR CODE HERE

print(f"Predicted salary for 2 years of experience: ${predictions[0]:.2f}")
print(f"Predicted salary for 10 years of experience: ${predictions[1]:.2f}")
